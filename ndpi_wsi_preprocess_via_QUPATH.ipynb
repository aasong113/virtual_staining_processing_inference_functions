# %%
import openslide
from openslide import open_slide
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import os
import glob

# %% [markdown]
# ### Split into Patches and then save as .png images.
#
# #### This takes in a magnification rescaled image based on the BIT microscope image and Hamamatsu slide scanner, and then splits the image into n x n patches.

# %%
import os
import random
import shutil
from glob import glob

def split_image_into_patches(image, patch_size, overlap, output_folder, handle="patch", extension = "png"):
    """
    Splits an image into n x n patches with overlap, and saves them to a folder.
    Only saves complete patches of the specified size.
    Args:
    - image: PIL image to split
    - patch_size: Size of the patches (e.g., (256, 256))
    - overlap: Overlap between patches (e.g., 50 for 50-pixel overlap)
    - output_folder: Folder to save the patches
    - handle: Prefix for the patch file name
    Returns:
    - None
    """
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)
    # Convert the image to a NumPy array
    np_image = np.array(image)
    # Get the dimensions of the image
    height, width = np_image.shape[0], np_image.shape[1]
    # Calculate the step size (patch size minus overlap)
    step = patch_size[0] - overlap
    patch_number = 1  # Counter for patches
    # Iterate through the image and extract patches
    for y in range(0, height - patch_size[0] + 1, step):
        for x in range(0, width - patch_size[1] + 1, step):
            # Check if the patch is within the image boundaries
            if y + patch_size[0] <= height and x + patch_size[1] <= width:
                # Extract the patch
                patch = np_image[y:y + patch_size[0], x:x + patch_size[1]]
                # Convert the patch to a PIL image
                patch_pil = Image.fromarray(patch)
                # Save the patch
                formatted = f"{patch_number:05d}"
                patch_filename = f"{handle}_{formatted}.{extension}"
                patch_pil.save(os.path.join(output_folder, patch_filename))
                patch_number += 1


def split_images_train_test(source_folder, output_root, train_ratio=0.99, seed=42):
    """
    Randomly splits .tif images in source_folder into train and test folders.

    Args:
        source_folder (str): Path to folder containing .tif images.
        output_root (str): Root folder where 'train/' and 'test/' will be created.
        train_ratio (float): Ratio of images to put in train set.
        seed (int): Random seed for reproducibility.
    """
    os.makedirs(os.path.join(output_root, 'train'), exist_ok=True)
    os.makedirs(os.path.join(output_root, 'test'), exist_ok=True)

    tif_images = glob(os.path.join(source_folder, "*.tif"))
    random.seed(seed)
    random.shuffle(tif_images)

    split_index = int(len(tif_images) * train_ratio)
    train_images = tif_images[:split_index]
    test_images = tif_images[split_index:]

    print(f"Total images: {len(tif_images)}")
    print(f"Train: {len(train_images)}")
    print(f"Test: {len(test_images)}")

    for img_path in train_images:
        shutil.move(img_path, os.path.join(output_root, 'train', os.path.basename(img_path)))

    for img_path in test_images:
        shutil.move(img_path, os.path.join(output_root, 'test', os.path.basename(img_path)))

# Example usage:
# split_images_train_test("/path/to/images", "/path/to/split_output")

import math

def rotate_and_crop_to_content(image, angle):
    """
    Rotate and crop to largest rectangle without black borders.
    Uses the correct formula for largest inscribed axis-aligned rectangle.
    """
    # For 90-degree increments, use transpose (no black borders)
    if angle % 90 == 0:
        angle = angle % 360
        if angle == 0:
            return image
        elif angle == 90:
            return image.transpose(Image.ROTATE_90)
        elif angle == 180:
            return image.transpose(Image.ROTATE_180)
        elif angle == 270:
            return image.transpose(Image.ROTATE_270)
    
    # For arbitrary angles, rotate and crop
    rotated = image.rotate(angle, expand=True, resample=Image.BICUBIC)
    
    # Get dimensions
    w, h = image.size
    angle_rad = math.radians(angle)
    
    # Calculate the largest inscribed rectangle
    # Formula from: https://stackoverflow.com/questions/16702966
    cos_a = abs(math.cos(angle_rad))
    sin_a = abs(math.sin(angle_rad))
    
    # Width and height of the largest inscribed rectangle
    if w >= h:
        new_w = (w * cos_a + h * sin_a - h) / (cos_a**2 / sin_a + sin_a)
        new_h = new_w * h / w
    else:
        new_h = (h * cos_a + w * sin_a - w) / (cos_a**2 / sin_a + sin_a)
        new_w = new_h * w / h
    
    # Alternative simpler but more conservative approach
    # This guarantees no black pixels but may crop more than necessary
    if new_w <= 0 or new_h <= 0:
        # Fallback: use conservative crop factor
        crop_factor = cos_a * sin_a / (cos_a + sin_a)
        new_w = int(w * crop_factor)
        new_h = int(h * crop_factor)
    else:
        new_w = int(new_w)
        new_h = int(new_h)
    
    # Get rotated image size and center crop
    rot_w, rot_h = rotated.size
    left = (rot_w - new_w) // 2
    top = (rot_h - new_h) // 2
    
    return rotated.crop((left, top, left + new_w, top + new_h))

# %%
def rotate_and_crop_safe(image, angle):
    """
    Rotate image and aggressively crop to ensure NO black pixels.
    Uses a conservative approach that crops more to guarantee clean edges.
    """
    import math
    
    # For 90-degree increments, use transpose (perfect rotation)
    if angle % 90 == 0:
        angle = angle % 360
        if angle == 0:
            return image
        elif angle == 90:
            return image.transpose(Image.ROTATE_90)
        elif angle == 180:
            return image.transpose(Image.ROTATE_180)
        elif angle == 270:
            return image.transpose(Image.ROTATE_270)
    
    # Rotate with expansion
    rotated = image.rotate(angle, expand=True, resample=Image.BICUBIC, fillcolor=(0, 0, 0))
    
    w, h = image.size
    angle_rad = math.radians(abs(angle))
    
    # Conservative crop: use the formula for the largest square that fits
    # This is more aggressive but guarantees no black pixels
    cos_a = abs(math.cos(angle_rad))
    sin_a = abs(math.sin(angle_rad))
    
    # For rectangle, use this conservative bound
    # The largest inscribed rectangle has dimensions:
    denominator = cos_a + sin_a
    if denominator > 0:
        new_w = int((w * cos_a * sin_a + h * cos_a * sin_a) / denominator)
        new_h = int((h * cos_a * sin_a + w * cos_a * sin_a) / denominator)
    else:
        new_w = int(min(w, h) * 0.7)
        new_h = int(min(w, h) * 0.7)
    
    # Make sure dimensions are positive and reasonable
    new_w = max(1, min(new_w, w))
    new_h = max(1, min(new_h, h))
    
    # Center crop from rotated image
    rot_w, rot_h = rotated.size
    left = (rot_w - new_w) // 2
    top = (rot_h - new_h) // 2
    
    cropped = rotated.crop((left, top, left + new_w, top + new_h))
    
    # Extra safety: check if we still have black corners and crop more if needed
    # Convert to numpy to check corners
    img_array = np.array(cropped)
    corner_size = 5  # Check 5x5 pixel corners
    
    # Check all 4 corners for black pixels (sum of RGB < 10)
    corners_have_black = (
        np.sum(img_array[:corner_size, :corner_size]) < 10 * corner_size * corner_size or
        np.sum(img_array[:corner_size, -corner_size:]) < 10 * corner_size * corner_size or
        np.sum(img_array[-corner_size:, :corner_size]) < 10 * corner_size * corner_size or
        np.sum(img_array[-corner_size:, -corner_size:]) < 10 * corner_size * corner_size
    )
    
    if corners_have_black:
        # Crop an additional 5% from each side
        safety_margin = 0.05
        new_w = int(new_w * (1 - 2 * safety_margin))
        new_h = int(new_h * (1 - 2 * safety_margin))
        left = (rot_w - new_w) // 2
        top = (rot_h - new_h) // 2
        cropped = rotated.crop((left, top, left + new_w, top + new_h))
    
    return cropped

# %%
# Magnification Information of the microscope and slide scanner. 

mpp_x = float(0.22034197073858627)
mpp_y = float(0.22034197073858627)
print(f"MPP X: {mpp_x} µm/pixel")
print(f"MPP Y: {mpp_y} µm/pixel")
PCO_pixel_size = 6.5 # microns
BIT_magnification = 40
reference_scale = PCO_pixel_size / BIT_magnification
scale_factor_x = mpp_x / reference_scale
scale_factor_y = mpp_x / reference_scale

print(f"x ratio: {scale_factor_x}")
print(f"y ratio: {scale_factor_y}")
# Out:
# MPP X: 0.22034197073858627 µm/pixel
# MPP Y: 0.22034197073858627 µm/pixel
# x ratio: 1.3559505891605308
# y ratio: 1.3559505891605308

# %%
slide_paths = r'C:\Users\durrlab-asong\Desktop\virtual_staining_training_data\duodenum\FFPE-HE\duodenum_crypts_online\cropped_to_train'
output_slide_path = os.path.join(slide_paths, "patches_shrinkage_compensation")
tif_imgs = glob(os.path.join(slide_paths, "*.jpg"))
print(len(tif_imgs))
patch_size = (512, 512)

patch_handle = "duodenum_crypts_lieberkuhn"
overlap = 350 # number of pixel overlap
img_ext = "tif"


# Account for shrinkage during dehydration
percent_shrinkage = 1  # 50% shrinkage means the final image is 50% of the original size 
shrinkage_compensation = 1 / percent_shrinkage  # 3.33x magnification

# Convert percent_shrinkage to string format (replace . with p)
shrinkage_str = str(percent_shrinkage).replace('.', 'p')
output_slide_path = os.path.join(slide_paths, f"patches_shrinkage_compensation={shrinkage_str}")

# Combine with existing scale factors
final_scale_x = scale_factor_x * shrinkage_compensation
final_scale_y = scale_factor_y * shrinkage_compensation

for i, tif_img in enumerate(tif_imgs):
    img_roi = Image.open(tif_img)

    # Rescale image. 
    image_roi = img_roi.convert('RGB')
    image_roi = np.array(image_roi)

    # rescale H&E Image for magnification of microscope and slide scanner and Rescale H&E image for shrinkage compensation during dehydration.
    rescaled_image_roi = cv.resize(image_roi, None, 
                               fx=final_scale_x, 
                               fy=final_scale_y, 
                               interpolation=cv.INTER_CUBIC)

    print(f"Rescaled image shape: {rescaled_image_roi.shape} and Original image shape: {image_roi.shape}")
    rescaled_image_roi = Image.fromarray(rescaled_image_roi)
    patch_handle_temp = f"{patch_handle}_roi_{i}"
    split_image_into_patches(rescaled_image_roi, patch_size, overlap, output_slide_path, handle=patch_handle_temp, extension=img_ext)

    # Augmentations
    # Rotate 90 degrees counter-clockwise
    rotated_30 = rotate_and_crop_to_content(rescaled_image_roi, 30)
    patch_handle_temp = f"{patch_handle}_roi_{i}_rot30"
    split_image_into_patches(rotated_30, patch_size, overlap, output_slide_path, handle=patch_handle_temp, extension=img_ext)

    rotated_90 = rotate_and_crop_to_content(rescaled_image_roi, 90)
    patch_handle_temp = f"{patch_handle}_roi_{i}_rot90"
    split_image_into_patches(rotated_90, patch_size, overlap, output_slide_path, handle=patch_handle_temp, extension=img_ext)

    rotated_270 = rotate_and_crop_to_content(rescaled_image_roi, 270)
    patch_handle_temp = f"{patch_handle}_roi_{i}_rot270"
    split_image_into_patches(rotated_270, patch_size, overlap, output_slide_path, handle=patch_handle_temp, extension=img_ext)
# Out:
# 14
# Rescaled image shape: (1839, 3489, 3) and Original image shape: (1356, 2573, 3)
# Rescaled image shape: (1546, 3045, 3) and Original image shape: (1140, 2246, 3)
# Rescaled image shape: (2620, 2517, 3) and Original image shape: (1932, 1856, 3)
# Rescaled image shape: (911, 1184, 3) and Original image shape: (672, 873, 3)
# Rescaled image shape: (1460, 1379, 3) and Original image shape: (1077, 1017, 3)
# Rescaled image shape: (1407, 2279, 3) and Original image shape: (1038, 1681, 3)
# Rescaled image shape: (816, 789, 3) and Original image shape: (602, 582, 3)
# Rescaled image shape: (2620, 3493, 3) and Original image shape: (1932, 2576, 3)
# Rescaled image shape: (2620, 1713, 3) and Original image shape: (1932, 1263, 3)
# Rescaled image shape: (960, 2114, 3) and Original image shape: (708, 1559, 3)
# Rescaled image shape: (2335, 765, 3) and Original image shape: (1722, 564, 3)
# Rescaled image shape: (1485, 1703, 3) and Original image shape: (1095, 1256, 3)
# Rescaled image shape: (1178, 1688, 3) and Original image shape: (869, 1245, 3)
# Rescaled image shape: (1801, 1158, 3) and Original image shape: (1328, 854, 3)

# %%
split_images_train_test(output_slide_path, output_slide_path, train_ratio=0.99, seed=42)
# Out:
# Total images: 3445
# Train: 3410
# Test: 35
