# %% [markdown]
# ### Load Data
#
# conda activate preprocess_data

# %%
import glob
import sys
import os
import re
import numpy as np
import tifffile as tiff
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import random
import glob

folder_path = "/home/durrlab/Desktop/Anthony/training_data_processing/"
sys.path.append(folder_path)
from processing_functions import *

# %%
root = "/media/durrlab/LaCie/MUSE_BIT_Human_Tissue_data/20250701_kidney_JH69436370/normal/MUSE-BIT/KidneyNormal3accepted"


BIT_tif_files = glob.glob(os.path.join(root, '*BIT*.tif'))
MUSE_Blue_tif_files = glob.glob(os.path.join(root, '*darksect_reg_MUSE_blue*.tif'))
MUSE_Green_tif_files = glob.glob(os.path.join(root, '*darksect_MUSE_green*.tif'))

print(f"Found {len(BIT_tif_files)} BIT files")
print(f"Found {len(MUSE_Blue_tif_files)} MUSE Blue files")
print(f"Found {len(MUSE_Green_tif_files)} MUSE Green files")
# Out:
# Found 0 BIT files
# Found 0 MUSE Blue files
# Found 0 MUSE Green files
